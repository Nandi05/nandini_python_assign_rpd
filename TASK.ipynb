# %% [markdown]
# ## Internship Task

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as mp

# %%
import seaborn as sb

# %%
data=pd.read_csv("data.csv")

# %%
data.head()
# Out:
#         Date  High Price  Low Price  Close Price  Total Traded Quantity  \
# 0  01-Jan-21     1443.00    1420.60      1425.05                4405469
# 1  04-Jan-21     1438.00    1399.00      1416.00                7870096
# 2  05-Jan-21     1430.75    1409.00      1426.70                7193412
# 3  06-Jan-21     1440.00    1413.10      1420.55               11067025
# 4  07-Jan-21     1432.60    1412.55      1416.25                9947421
#
#    Turnover (in lacs)  No. of Contracts
# 0         63155.33422             24302
# 1        111534.73280             40233
# 2        102141.60600             49022
# 3        157545.11010             62408
# 4        141486.23310             47083

# %% [markdown]
# ## Renaming Columns

# %%
data.rename({'Date':'date','High Price':'high','Low Price':'low','Total Traded Quantity':'trade','Turnover (in lacs)':'turnover_in_lakhs','No. of Contracts':'contracts'},axis=1)
# Out:
#           date     high      low  Close Price     trade  turnover_in_lakhs  \
# 0    01-Jan-21  1443.00  1420.60      1425.05   4405469        63155.33422
# 1    04-Jan-21  1438.00  1399.00      1416.00   7870096       111534.73280
# 2    05-Jan-21  1430.75  1409.00      1426.70   7193412       102141.60600
# 3    06-Jan-21  1440.00  1413.10      1420.55  11067025       157545.11010
# 4    07-Jan-21  1432.60  1412.55      1416.25   9947421       141486.23310
# ..         ...      ...      ...          ...       ...                ...
# 176  20-Sep-21  1581.70  1558.00      1559.85   4390805        68894.37483
# 177  21-Sep-21  1568.65  1528.95      1551.95   7387498       114102.02960
# 178  22-Sep-21  1550.15  1530.00      1533.70   5291101        81323.32796
# 179  23-Sep-21  1572.00  1542.00      1570.00   6832152       106667.87040
# 180  24-Sep-21  1607.95  1575.00      1601.55  10403351       165728.94840
#
#      contracts
# 0        24302
# 1        40233
# 2        49022
# ...

# %%
data.rename({'Date':'date','High Price':'high','Low Price':'low','Total Traded Quantity':'trade','Turnover (in lacs)':'turnover_in_lakhs','No. of Contracts':'contracts'},axis=1,inplace=True)

# %% [markdown]
# ## Inserting a new Column

# %%
data['difference']=data['high']-data['low']

# %%
data.head()
# Out:
#         date     high      low  Close Price     trade  turnover_in_lakhs  \
# 0  01-Jan-21  1443.00  1420.60      1425.05   4405469        63155.33422
# 1  04-Jan-21  1438.00  1399.00      1416.00   7870096       111534.73280
# 2  05-Jan-21  1430.75  1409.00      1426.70   7193412       102141.60600
# 3  06-Jan-21  1440.00  1413.10      1420.55  11067025       157545.11010
# 4  07-Jan-21  1432.60  1412.55      1416.25   9947421       141486.23310
#
#    contracts  difference
# 0      24302       22.40
# 1      40233       39.00
# 2      49022       21.75
# 3      62408       26.90
# 4      47083       20.05

# %% [markdown]
# ## Saving the processed data

# %%
data.to_csv(r"C:\Users\test\Desktop\ml task\processed_data.csv")

# %%
data2=pd.read_csv('processed_data.csv')

# %%
data2.head()
# Out:
#    Unnamed: 0       date     high      low  Close Price     trade  \
# 0           0  01-Jan-21  1443.00  1420.60      1425.05   4405469
# 1           1  04-Jan-21  1438.00  1399.00      1416.00   7870096
# 2           2  05-Jan-21  1430.75  1409.00      1426.70   7193412
# 3           3  06-Jan-21  1440.00  1413.10      1420.55  11067025
# 4           4  07-Jan-21  1432.60  1412.55      1416.25   9947421
#
#    turnover_in_lakhs  contracts  difference
# 0        63155.33422      24302       22.40
# 1       111534.73280      40233       39.00
# 2       102141.60600      49022       21.75
# 3       157545.11010      62408       26.90
# 4       141486.23310      47083       20.05

# %%
data2.drop("Unnamed: 0", inplace=True,axis=1)

# %%
data2.head()
# Out:
#         date     high      low  Close Price     trade  turnover_in_lakhs  \
# 0  01-Jan-21  1443.00  1420.60      1425.05   4405469        63155.33422
# 1  04-Jan-21  1438.00  1399.00      1416.00   7870096       111534.73280
# 2  05-Jan-21  1430.75  1409.00      1426.70   7193412       102141.60600
# 3  06-Jan-21  1440.00  1413.10      1420.55  11067025       157545.11010
# 4  07-Jan-21  1432.60  1412.55      1416.25   9947421       141486.23310
#
#    contracts  difference
# 0      24302       22.40
# 1      40233       39.00
# 2      49022       21.75
# 3      62408       26.90
# 4      47083       20.05

# %% [markdown]
# ## Correlation Matrix

# %%
correlation= data.corr()

# %%
sb.heatmap(correlation)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Saving processed_data.csv into database
